# %%
import pandas as pd 
import folium 
from sklearn.cluster import KMeans 
import requests

# %%
df=pd.read_csv('Toronto_upgraded.csv')
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    Latitude  Longitude
# 0  43.75245  -79.32991
# 1  43.73057  -79.31306
# 2  43.65512  -79.36264
# 3  43.72327  -79.45042
# 4  43.66253  -79.39188

# %%
df.groupby('Borough').sum()
# Out:
#                     Latitude   Longitude
# Borough
# Central Toronto    393.31704  -714.59186
# Downtown Toronto   829.45616 -1508.30135
# East Toronto       218.33963  -396.68567
# East York          218.49543  -396.66546
# Etobicoke          523.92313  -954.47664
# Mississauga         43.64869   -79.38544
# North York        1049.99924 -1906.32536
# Scarborough        744.04519 -1347.22004
# West Toronto       261.91026  -476.67159
# York               218.45665  -397.36555

# %%
latitude=43.6532
longitude=-79.3832

# %%
# create map of New York using latitude and longitude values
map_tornto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tornto)  
    
map_tornto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
